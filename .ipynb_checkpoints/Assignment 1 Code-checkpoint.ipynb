# %% [markdown]
# # 1.1

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
from matplotlib.pyplot import figure
from random import randint
import seaborn as sns
from math import sqrt
from statistics import variance
from numpy.linalg import inv

np.random.seed(7)

# %%
#value initialization
N=240
V=441
x1=21
x2=21
x1x2=21*21
nsrcs=6

# %%
#initializing initial TC values
AV = [0,20,0,0,0,0]
IV = [30,45,60,40,40,40]
Ones = [15,20,25,15,20,25]

TC = np.zeros((240,6))

#create TC sources according to conditions
for i in range(len(AV)):
    TC[:,i] = np.zeros((1,240))
    start = AV[i]
    while start < (N-20) :
        for j in range(Ones[i]):
            TC[:,i][start+j] = np.ones(1)
        start += IV[i]
        
#standardize TC
TC = preprocessing.scale(TC)

# %%
#plot TC subplots
fig, axs = plt.subplots(2,3, figsize = (15,10))

axs[0, 0].plot(TC[:,0])
axs[0, 0].set_title("TC 1")
axs[0, 1].plot(TC[:,1])
axs[0, 1].set_title("TC 2")
axs[0, 2].plot(TC[:,2])
axs[0, 2].set_title("TC 3")
axs[1, 0].plot(TC[:,3])
axs[1, 0].set_title("TC 4")
axs[1, 1].plot(TC[:,4])
axs[1, 1].set_title("TC 5")
axs[1, 2].plot(TC[:,5])
axs[1, 2].set_title("TC 6")

plt.savefig('plots/question_1_1.jpg')

# %% [markdown]
# Standardize instead of Normalize if we Normalize then the mean will not be centered arund 0.

# %% [markdown]
# # 1.2

# %%
#create correlation map between TC sources
sns.heatmap(np.corrcoef(TC,rowvar=False), annot = True)
plt.savefig("plots/question_1_2.jpg")

# %% [markdown]
# From the Correlation Matrix, we see that TC 3 and 4 and TC 4 and 5 are most correlated.

# %% [markdown]
# # 1.3

# %%
#initialize SM according to set conditions

tmpSM_0 = np.zeros((21,21))
tmpSM_0[2:6,2:6] = np.ones((4,4))

tmpSM_1 = np.zeros((21,21))
tmpSM_1[2:6,15:19] = np.ones((4,4))

tmpSM_2 = np.zeros((21,21))
tmpSM_2[8:13, 2:6] = np.ones((5,4))

tmpSM_3 = np.zeros((21,21))
tmpSM_3[8:13, 15:19] = np.ones((5,4))

tmpSM_4 = np.zeros((21,21))
tmpSM_4[15:19, 2:6] = np.ones((4,4))

tmpSM_5 = np.zeros((21,21))
tmpSM_5[15:19, 15:19] = np.ones((4,4))

# %%
#plot SM subplots

fig, axs = plt.subplots(2,3, figsize = (18,10))
sns.heatmap(tmpSM_0,ax=axs[0,0]).set_title("SM 1", fontsize=15)
sns.heatmap(tmpSM_1,ax=axs[0,1]).set_title("SM 2", fontsize=15)
sns.heatmap(tmpSM_2,ax=axs[0,2]).set_title("SM 3", fontsize=15)
sns.heatmap(tmpSM_3,ax=axs[1,0]).set_title("SM 4", fontsize=15)
sns.heatmap(tmpSM_4,ax=axs[1,1]).set_title("SM 5", fontsize=15)
sns.heatmap(tmpSM_5,ax=axs[1,2]).set_title("SM 6", fontsize=15)

plt.tight_layout()
plt.savefig("plots/question_1_3.jpg")

# %%
#combine individual SMs into one SM matrix

tmpSM=np.empty((6),dtype=object)
tmpSM[0]=tmpSM_0
tmpSM[1]=tmpSM_1
tmpSM[2]=tmpSM_2
tmpSM[3]=tmpSM_3
tmpSM[4]=tmpSM_4
tmpSM[5]=tmpSM_5

# %%
#reshape to size 6x441

SM=np.empty((6,441))
for i in range(len(tmpSM)):
    SM[i]=tmpSM[i].flatten()

# %%
#correlation map between SM sources

sns.heatmap(np.corrcoef(SM), annot = True)
plt.savefig("plots/question_1_3_a.jpg")

# %% [markdown]
# From the CM we can see that these vectored SMs are not correlated not necessarily independent. Standardization is not important because each vectors already have the same mean and standard deviation so standardization does not change anything.

# %% [markdown]
# # 1.4

# %%
#create temporal and spatial noise sources

temporal_source=np.random.normal(0,sqrt(0.25),(240,6))
spatial_source=np.random.normal(0,sqrt(0.015),(6,441))

# %%
#correlation amongst temporal and spatial noise sources

temp_corr = np.corrcoef(temporal_source,rowvar=False)
spat_corr = np.corrcoef(spatial_source)

# %%
#plot correlation map between temporal and spatial sources

fig, axs = plt.subplots(1,2, figsize = (15,5))
sns.heatmap(temp_corr,annot=True, ax=axs[0]).set_title("Correlation between Temporal Sources")
sns.heatmap(spat_corr, annot=True,ax=axs[1]).set_title("Correlation between Spatial Sources")
plt.savefig("plots/question_1_4.jpg")

# %%
#plot histogram of temporal and spatial sources

fig, axs = plt.subplots(1,2, figsize = (15,5))
sns.histplot(temporal_source, binrange = (-1.5,1.5), ax=axs[0]).set_title('Temporal Sources')
sns.histplot(spatial_source.T, binrange = (-0.4,0.4), ax=axs[1]).set_title('Spatial Sources')
plt.savefig("plots/question_1_4_1.jpg")

# %%
#plot a subset of the correlation between the product of the noise sources

product = np.matmul(temporal_source, spatial_source)
sns.heatmap(np.corrcoef(product[:8,:8]),annot=True)
plt.savefig("plots/question_1_4_2.jpg")

# %% [markdown]
# We can see that none of the sources are correlated for each noise type. This is expected because it is randomnly generated noise which should result in no correlations. The histogram shows a normal distribution and fulfills the mean and variance = 1.96 criteria relating to 0.25, 0.015, and zero mean. There is a prouct correlated across V number of variables based on the sample we plotted.

# %% [markdown]
# # 1.5

# %%
#generate matrix X

X=np.matmul(TC+temporal_source,SM+spatial_source)

# %%
#generate 100 random time series from X

plt.figure(figsize=(20,10))
plt.xlim(0,240)
plt.ylim(-3,3)
plt.ylabel("Value", fontsize=20)
plt.xlabel("N",fontsize=20)
for i in range(0,100):
    value = randint(0,440)
    plt.plot(X[:,value])
    
plt.savefig("plots/question_1_5.jpg")

# %%
#plot variance of all 441 variables

var = np.empty((441,1))
for i in range(0,441):
    var[i]=variance(X[:,i])

plt.plot(var)
plt.ylabel("Variance")
plt.xlabel("Variables")
plt.savefig("plots/question_1_5_1.jpg")

# %% [markdown]
# We can see that there are inconsistent variances throughout the variables, signaling the differences because of noise.

# %%
#Standardizing dataset X

X = preprocessing.scale(X)

# %% [markdown]
# The product can exist because they are shape compatible and this can be incorporated as an Error Term to signify noise. Plot shows inconsistent variance distribution amongst the sources.

# %% [markdown]
# # 2.1

# %%
#estimate A and D using Least Squares Regression

A_lsr = inv(np.matmul(TC.T,TC))
A_lsr = np.matmul(A_lsr,TC.T)
A_lsr = np.matmul(A_lsr,X)
D_lsr = np.matmul(X,A_lsr.T)

# %%
#plot retrieved spatial maps and time courses from Alsr and Dlsr

fig, axs = plt.subplots(6, 2, figsize = (10,15))

for i in range(6):
    count = i + 1
    sns.heatmap(abs(A_lsr[i]).reshape(21,21),vmin=-1, vmax=1, ax=axs[i,0]).set_title("Retrieved Spatial Maps %i" %count)
    axs[i,1].plot(D_lsr[:,0])
    axs[i,1].set_title("Retrieved Time Courses %i" %count)

plt.tight_layout()
plt.savefig('plots/question_2_1.jpg')

# %%
#show linear relationship between 3rd column of Dlsr and 30th column of standardised X (or 9th row 2nd pixel due to Python reshaping differences)
#constrast this relationship with 4th column of Dlsr and 30th column of standardised X

fig, axs = plt.subplots(1,2, figsize = (15,5))
sns.scatterplot(D_lsr.T[2], X.T[9*21 + 2],ax=axs[0]).set_title("3rd Column of Dlsr and 30th Column of Standardized X")
axs[1].scatter(D_lsr[:,3], X[:,29])
axs[1].set_title("4th Column of Dlsr and 30th Column of Standardized X")
plt.savefig("plots/question_2_1_1.jpg")
# Out:
# c:\users\janice\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 2.2

# %%
#estimate Ridge Regression parameters A_rr and D_rr

lambda_hat=0.5*441
A_rr=inv(np.matmul(TC.T,TC)+lambda_hat*np.identity(6))
A_rr=np.matmul(A_rr,TC.T)
A_rr=np.matmul(A_rr,X)
D_rr=np.matmul(X,A_rr.T)

# %%
#comparing Ridge Regression to Least Squares Regression using its two absolute corelation vectors

C_tlsr=np.empty((6,1))
C_trr=np.empty((6,1))

for i in range(6):
    corr = np.corrcoef(TC[:,i],D_rr[:,i])
    C_trr[i]=abs(corr[1,0])
print("C_trr: {:.4f}".format(sum(C_trr)[0]))

for i in range(6):
    corr = np.corrcoef(TC[:,i],D_lsr[:,i])
    C_tlsr[i]=abs(corr[1,0])
print("C_tlsr: {:.4f}".format(sum(C_tlsr)[0]))
# Out:
# C_trr: 5.4633
# C_tlsr: 5.2287

# %%
#for lambda = 1000 estimate A_rr

lambda_hat_1000=1000
A_rr_1000=inv(np.matmul(TC.T,TC)+lambda_hat_1000*np.identity(6))
A_rr_1000=np.matmul(A_rr_1000,TC.T)
A_rr_1000=np.matmul(A_rr_1000,X)

# %%
#plot the first vector from A_rr_1000 and compare with same vectore from A_lsr

fig, axs = plt.subplots(1,2, figsize = (15,5))
axs[0].plot(A_rr_1000[:,0])
axs[0].set_ylim(-0.5,0.5)
axs[0].set_title("ARR")
axs[1].plot(A_lsr[:,0])
axs[1].set_ylim(-0.5,0.5)
axs[1].set_title("ALSR")
plt.savefig("plots/question_2_2.jpg")

# %% [markdown]
# # 2.3

# %%
#estimate Lasso Regression parameters A_lr and D_lr and sum of MSE for different values of rho 

#21 values of pho between 0 and 1 with 0.05 intervals
p = np.arange(0,1.05,0.05)

#step formula
step = 1/(np.linalg.norm(np.matmul(TC, TC.T), 'fro')*1.1)

#store average MSE value for each value of rho
avg_MSE = []

#formula of Lasso Regression from assignment
for val in p:
    MSE = []
    for i in range(10):
        
        #generate new dataset X every iteration with new temporal and spatial sources
        temporal_source=np.random.normal(0,sqrt(0.25),(240,6))
        spatial_source=np.random.normal(0,sqrt(0.015),(6,441))
        X_2=np.matmul(TC+temporal_source,SM+spatial_source)
        
        #preprocess X
        X_2=preprocessing.scale(X_2)
        
        #thr = rho x N x step
        thr=val*N*step
        
        Ao=np.zeros((nsrcs,1))
        A=np.zeros((nsrcs,1))
        Alr=np.zeros((nsrcs,x1x2))
        
        #reshaping done to make it adaptable in Python from R
        #code adapted from given R code in assignment pdf
        
        for k in range(0,x1x2):
            sub_A =(X_2[:,k].reshape(X_2.shape[0],) - np.matmul(TC, Ao).reshape(X.shape[0],))
            A = Ao.reshape(Ao.shape[0],) + step*(np.matmul(TC.T, sub_A)).reshape(Ao.shape[0])
            A = (1/(1+thr))*np.sign(A)*np.maximum(np.repeat(0, nsrcs), abs(A)-thr)
            
            for i in range(0,10):
                Ao=A
                A = Ao + step*(np.matmul(TC.T, X_2[:,k] - np.matmul(TC, Ao)))
                A = (1/(1+thr)) * (np.sign(A) * np.maximum(np.repeat(0, nsrcs), abs(A) - thr))
            Alr[:,k] = A  
        
        #D = X(AT)
        Dlr=np.matmul(X_2,Alr.T)
        
        #calculate MSE
        result = sum(sum((X_2 - np.matmul(Dlr, Alr))**2)) / (N*V)
        MSE.append(result)
    
    #calculate and store average MSE for each value of rho
    avg_MSE.append(np.average(MSE))

# %%
#plot average MSE over 10 realizations and 21 values of rho

fig = plt.figure(figsize=(8,8))
ax = plt.axes()

ax.plot(p, avg_MSE)
ax.set_ylabel("MSE", fontsize=10)
ax.set_xlabel("Rho", fontsize=10)
plt.savefig("plots/question_2_3.jpg")

# %%
#minimum value of rho and MSE

print("Minimum MSE: {:.4}".format(min(avg_MSE)))
print("Value of rho: {:.1}".format(p[avg_MSE.index(min(avg_MSE))]))
# Out:
# Minimum MSE: 0.5303
# Value of rho: 0.6

# %% [markdown]
# Minimum MSE is found at 0.6 with an average MSE of 0.5303. It is okay to select this value for it is relatively in the middle betwen 0 and 1. MSE started to increase again or LR diverged again when rho is larger than 0.6.

# %% [markdown]
# # 2.4

# %%
#estimate Lasso Regression parameters A and D for rho = 0.6
#code the same as question 2.3 except rho is 0.6

thr=0.6*N*step
Ao=np.zeros((nsrcs,1))
A=np.zeros((nsrcs,1))
Alr_rho=np.zeros((nsrcs,x1x2))

for k in range(0,x1x2):

    sub_A =(X[:,k].reshape(X.shape[0],) - np.matmul(TC, Ao).reshape(X.shape[0],))
    A = Ao.reshape(Ao.shape[0],) + step*(np.matmul(TC.T, sub_A)).reshape(Ao.shape[0])
    A = (1/(1+thr))*np.sign(A)*np.maximum(np.repeat(0, nsrcs), abs(A)-thr)

    for i in range(0,10):
        Ao=A
        A = Ao + step*(np.matmul(TC.T, X[:,k] - np.matmul(TC, Ao)))
        A = (1/(1+thr)) * (np.sign(A) * np.maximum(np.repeat(0, nsrcs), abs(A) - thr))
    Alr_rho[:,k] = A  
Dlr_rho=np.matmul(X,Alr_rho.T)

# %%
#estimate four absolute correlation vectors between (TC and D) and (SM and A) from Lasso and Ridge Regression

C_trr=np.empty((6,1))
C_srr=np.empty((6,1))
C_tlr=np.empty((6,1))
C_slr=np.empty((6,1))

#correlation vectors between TC and D_lr with rho = 0.6
for i in range(6):
    corr = np.corrcoef(TC[:,i],Dlr_rho[:,i])
    C_tlr[i]=abs(corr[1,0])
print("C_tlr: {:.4f}".format(sum(C_tlr)[0]))

#correlation vectors between TC and D_rr
for i in range(6):
    corr = np.corrcoef(TC[:,i],D_rr[:,i])
    C_trr[i]=abs(corr[1,0])
print("C_trr: {:.4f}".format(sum(C_trr)[0]))

#correlation vectors between SM and A_lr with rho = 0.6
for i in range(6):
    corr = np.corrcoef(SM[i],Alr_rho[i])
    C_slr[i]=abs(corr[1,0])
print("C_slr: {:.4f}".format(sum(C_slr)[0]))

#correlation vectors between SM and A_rr
for i in range(6):
    corr = np.corrcoef(SM[i],A_rr[i])
    C_srr[i]=abs(corr[1,0])
print("C_srr: {:.4f}".format(sum(C_srr)[0]))
# Out:
# C_tlr: 5.4746
# C_trr: 5.4633
# C_slr: 4.6730
# C_srr: 2.5560

# %%
#plot retrieved spatial maps and time courses from both RR and LR to compare

fig, axs = plt.subplots(6, 4, figsize = (15,12))

for i in range(6):
    count=i+1
    sns.heatmap(abs(A_rr[i]).reshape(21,21),ax=axs[i,0]).set_title("Retrieved Spatial Maps (A_RR) %i" %count)
    axs[i,1].plot(D_rr[:,i])
    axs[i,1].set_title("Retrieved Time Courses (D_RR) %i" %count)
    sns.heatmap(abs(Alr_rho[i]).reshape(21,21),ax=axs[i,2]).set_title("Retrieved Spatial Maps (A_LR) %i" %count)
    axs[i,3].plot(Dlr_rho[:,i])
    axs[i,3].set_title("Retrieved Time Courses (D_LR) %i" %count)

plt.tight_layout()
plt.savefig('plots/question_2_4.jpg')

# %% [markdown]
# The large amounts of false positives generated through Ridge Regression can be explained through its inability to filter our noise which decreases its accuracy. Since this is carried into its estimate of A this affects their estimate of D as well which causes overfitting.

# %% [markdown]
# # 2.5

# %%
#perform PC on TC
[U,V,W] = np.linalg.svd(TC,full_matrices=False)
Z = U

# %%
#plot eigenvalues
plt.plot(V)
plt.savefig("plots/question_2_5_1.jpg")

# %%
#plot time source obtained from Z and original source TC side by side

fig, axs = plt.subplots(6, 2, figsize = (10,15))

for i in range(6):
    count = i + 1
    axs[i,0].plot(Z[:,i])
    axs[i,0].set_title("Z Regressors %i" %count)
    axs[i,1].plot(TC[:,i])
    axs[i,1].set_title("Source TC %i" %count)

plt.tight_layout()
plt.savefig('plots/question_2_5_2.jpg')

# %%
#apply lasso regression on X with rho = 0.001
#code the same as question 2.4 just changed TC to Z

step = 1/(np.linalg.norm(np.matmul(Z, Z.T), 'fro')*1.1)
thr=0.001*N*step
Ao=np.zeros((nsrcs,1))
A=np.zeros((nsrcs,1))
A_pcr=np.zeros((nsrcs,x1x2))

for k in range(0,x1x2):

    sub_A =(X[:,k].reshape(X.shape[0],) - np.matmul(Z, Ao).reshape(X.shape[0],))
    A = Ao.reshape(Ao.shape[0],) + step*(np.matmul(Z.T, sub_A)).reshape(Ao.shape[0])
    A = (1/(1+thr))*np.sign(A)*np.maximum(np.repeat(0, nsrcs), abs(A)-thr)

    for i in range(0,10):
        Ao=A
        A = Ao + step*(np.matmul(Z.T, X[:,k] - np.matmul(Z, Ao)))
        A = (1/(1+thr)) * (np.sign(A) * np.maximum(np.repeat(0, nsrcs), abs(A) - thr))
    A_pcr[:,k] = A  
D_pcr=np.matmul(X,A_pcr.T)

# %%
#plot spatial maps and time courses for PCR

fig, axs = plt.subplots(6, 2, figsize = (10,15))

for i in range(6):
    count = i + 1
    sns.heatmap(abs(A_pcr[i]).reshape(21,21),vmin=-1, vmax=1, ax=axs[i,0]).set_title("Retrieved Spatial Maps (A pcr) %i" %count)
    axs[i,1].plot(D_pcr[:,i])
    axs[i,1].set_title("Retrieved Time Courses (D pcr) %i" %count)

plt.tight_layout()
plt.savefig('plots/question_2_5.jpg')
